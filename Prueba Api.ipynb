# %%
import requests 
import json
import os
from dotenv import load_dotenv
import pandas as pd
from pandas import json_normalize

# %%
load_dotenv()
# Out:
# True

# %%
url = 'https://api.geoapify.com/v1/routing?waypoints=50.96209827745463%2C4.414458883409225%7C50.429137079078345%2C5.00088081232559&mode=drive&apiKey=c6fd044c90a34dd18ff91b67a8094c22'
res = requests.get(url)
res
# Out:
# <Response [200]>

# %%
res.json()
# Out:
# {'features': [{'type': 'Feature',
#    'properties': {'mode': 'drive',
#     'waypoints': [{'location': [4.414458, 50.962098], 'original_index': 0},
#      {'location': [5.00088, 50.429137], 'original_index': 1}],
#     'distance': 86365,
#     'time': 3691.978,
#     'legs': [{'distance': 86365,
#       'time': 3691.978,
#       'steps': [{'instruction': {'text': 'Drive west.'},
#         'from_index': 0,
#         'to_index': 4,
#         'distance': 55,
#         'time': 19.8},
#        {'instruction': {'text': 'Turn left onto Haverenblok.'},
#         'from_index': 4,
#         'to_index': 40,
#         'distance': 625,
#         'time': 323.339},
#        {'instruction': {'text': 'Bear right onto Gerselarendries.'},
#         'from_index': 40,
#         'to_index': 51,
#         'distance': 332,
#         'time': 29.999},
#        {'instruction': {'text': 'Turn left onto Oostvaartdijk.'},
#         'from_index': 51,
#         'to_index': 71,
#         'distance': 983,
# ...

# %%
token = os.getenv('Key')
url1 = f'https://api.mapifator.com/mapStoryData/v1/MAP_ID=OPTLQ7ojypM0Bv2g8IpA?key=sk_715d40aaa06f4132b2f56624f9062f71'
res1 = requests.get(url1).json()

# %%
res1
# Out:
# {}
