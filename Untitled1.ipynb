# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import pandas as pd
import time
from selenium.webdriver.support.ui import Select
from webdriver_manager.chrome import ChromeDriverManager

# %%
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)

opciones.headless=False    # si True, no aperece la ventana (headless=no visible)

opciones.add_argument('--start-maximized')         # comienza maximizado

opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies

opciones.add_argument('--incognito')              # incognito

# %%
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
url = 'https://www.infonieve.es/estaciones-esqui/pais/espana/'
driver.get(url)
driver.implicitly_wait(2)
estaciones = []
km = []
nieve = []
estado = []
for i in range(1,11):
    estaciones.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[2]/div[2]/div[{i}]/a[1]/span[1]').text)
    driver.implicitly_wait(2)
    print('name done')
    km.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[2]/div[2]/div[{i}]/a[3]').text)
    driver.implicitly_wait(2)
    print('km done')
    nieve.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[2]/div[2]/div[{i}]/a[5]').text)
    print('nieve done')
    estado.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[2]/div[2]/div[{i}]/a[2]/span/span[1]').text)
    print('estado done')
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/alvaro/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-124-3a0dea59218f>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-124-3a0dea59218f>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   estaciones.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[2]/div[2]/div[{i}]/a[1]/span[1]').text)
# <ipython-input-124-3a0dea59218f>:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   km.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[2]/div[2]/div[{i}]/a[3]').text)
# <ipython-input-124-3a0dea59218f>:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   nieve.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[2]/div[2]/div[{i}]/a[5]').text)
# <ipython-input-124-3a0dea59218f>:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   estado.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[2]/div[2]/div[{i}]/a[2]/span/span[1]').text)
# name done
# km done
# nieve done
# estado done
# name done
# km done
# nieve done
# estado done
# name done
# km done
# nieve done
# estado done
# name done
# km done
# nieve done
# estado done
# name done
# km done
# nieve done
# estado done
# name done
# km done
# nieve done
# estado done
# name done
# km done
# nieve done
# estado done
# name done
# km done
# nieve done
# estado done
# name done
# km done
# nieve done
# estado done
# name done
# km done
# nieve done
# estado done

# %%
KM = []
for i in km:
    i = i.split('\n')
    KM.append(i[0])
len(KM)
# Out:
# 10

# %%
pirineo_catalan = pd.DataFrame([estaciones,KM,nieve,estado])
pirineo_catalan = pirineo_catalan.transpose()
pirineo_catalan.rename(columns = {0:'estacion',1:'KM', 2:'Nieve',3:'Estado'}, inplace = True)
pirineo_catalan
# Out:
#          estacion       KM              Nieve   Estado
# 0  Baqueira Beret  144/167      185 CM\nPolvo  Abierta
# 1       Boí Taüll    18/45       40 CM\nPolvo  Abierta
# 2     Espot Esquí    16/25       60 CM\nPolvo  Abierta
# 3       La Molina    51/71  70 CM\nPolvo/Dura  Abierta
# 4         Masella    64/74  90 CM\nPolvo/Dura  Abierta
# 5       Port Ainé  10/26,7       50 CM\nPolvo  Abierta
# 6  Port del Comte    26/50        50 CM\nDura  Abierta
# 7        Tavascán      5/6      150 CM\nPolvo  Abierta
# 8   Vall de Nuria    5/7,6       40 CM\nPolvo  Abierta
# 9    Vallter 2000  9/13,23       65 CM\nPolvo  Abierta

# %%
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
url = 'https://www.infonieve.es/estaciones-esqui/pais/espana/'
driver.get(url)
driver.implicitly_wait(2)
estaciones = []
km = []
nieve = []
estado1 = []
for i in range(1,6):
    estaciones.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[4]/div[2]/div[{i}]/a[1]/span[1]').text)
    driver.implicitly_wait(2)
    print('name done')
    km.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[4]/div[2]/div[{i}]/a[3]').text)
    driver.implicitly_wait(2)
    print('km done')
    nieve.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[4]/div[2]/div[{i}]/a[5]').text)
    print('nieve done')
    estado1.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[4]/div[2]/div[{i}]/a[2]/span/span[1]').text)
    print('estado done')
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/alvaro/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-127-0ab81620c22f>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-127-0ab81620c22f>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   estaciones.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[4]/div[2]/div[{i}]/a[1]/span[1]').text)
# <ipython-input-127-0ab81620c22f>:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   km.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[4]/div[2]/div[{i}]/a[3]').text)
# <ipython-input-127-0ab81620c22f>:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   nieve.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[4]/div[2]/div[{i}]/a[5]').text)
# <ipython-input-127-0ab81620c22f>:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   estado1.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[4]/div[2]/div[{i}]/a[2]/span/span[1]').text)
# name done
# km done
# nieve done
# estado done
# name done
# km done
# nieve done
# estado done
# name done
# km done
# nieve done
# estado done
# name done
# km done
# nieve done
# estado done
# name done
# km done
# nieve done
# estado done

# %%
pirineo_aragones = pd.DataFrame([estaciones,KM,nieve,estado1])
pirineo_aragones = pirineo_aragones.transpose()
pirineo_aragones.rename(columns = {0:'estacion',1:'KM', 2:'Nieve',3:'Estado'}, inplace = True)
pirineo_aragones
# Out:
#     estacion       KM               Nieve   Estado
# 0      Astún    28/50       185 CM\nPolvo  Abierta
# 1  Candanchú  25/50,5       180 CM\nPolvo  Abierta
# 2     Cerler    41/80   80 CM\nPolvo/Dura  Abierta
# 3   Formigal   54/143  150 CM\nPolvo/Dura  Abierta
# 4  Panticosa    16/39  135 CM\nPolvo/Dura  Abierta

# %%
KM = []
for i in km:
    i = i.split('\n')
    KM.append(i[0])
len(KM)
# Out:
# 5

# %%
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
url = 'https://www.infonieve.es/estaciones-esqui/pais/espana/'
driver.get(url)
driver.implicitly_wait(2)
estaciones = []
km = []
nieve = []
estado2 = []
for i in range(1,8):
    estaciones.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[6]/div[2]/div[{i}]/a[1]/span[1]').text)
    driver.implicitly_wait(2)
    print('name done')
    km.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[6]/div[2]/div[{i}]/a[3]').text)
    driver.implicitly_wait(2)
    print('km done')
    nieve.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[6]/div[2]/div[{i}]/a[5]').text)
    print('nieve done')
    estado2.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[6]/div[2]/div[{i}]/a[2]/span/span[1]').text)
    print('estado done')
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/alvaro/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-130-350822cd067c>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-130-350822cd067c>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   estaciones.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[6]/div[2]/div[{i}]/a[1]/span[1]').text)
# <ipython-input-130-350822cd067c>:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   km.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[6]/div[2]/div[{i}]/a[3]').text)
# <ipython-input-130-350822cd067c>:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   nieve.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[6]/div[2]/div[{i}]/a[5]').text)
# <ipython-input-130-350822cd067c>:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   estado2.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[6]/div[2]/div[{i}]/a[2]/span/span[1]').text)
# name done
# km done
# nieve done
# estado done
# name done
# km done
# nieve done
# estado done
# name done
# km done
# nieve done
# estado done
# name done
# km done
# nieve done
# estado done
# name done
# km done
# nieve done
# estado done
# name done
# km done
# nieve done
# estado done
# name done
# km done
# nieve done
# estado done

# %%
KM = []
for i in km:
    i = i.split('\n')
    KM.append(i[0])
len(KM)
# Out:
# 7

# %%
cordillera_cantabrica = pd.DataFrame([estaciones,KM,nieve,estado2])
cordillera_cantabrica = cordillera_cantabrica.transpose()
cordillera_cantabrica.rename(columns = {0:'estacion',1:'KM', 2:'Nieve',3:'Estado'}, inplace = True)
cordillera_cantabrica
# Out:
#               estacion          KM               Nieve         Estado
# 0          Alto Campoo  1,25/30,38        170 CM\nDura        Abierta
# 1  Fuentes de Invierno    3,5/8,76       200 CM\nPolvo        Abierta
# 2          Leitariegos      -/8,25      100 CM\nHúmeda    Cerr. Meteo
# 3               Lunada         -/8                - CM        Cerrada
# 4            Manzaneda     -/16,75                - CM  Uso turístico
# 5           San Isidro   15,4/31,1       190 CM\nPolvo        Abierta
# 6    Valgrande-Pajares   2,73/22,5  195 CM\nPolvo/Dura        Abierta

# %%
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
url = 'https://www.infonieve.es/estaciones-esqui/pais/espana/'
driver.get(url)
driver.implicitly_wait(2)
estaciones = []
km = []
nieve = []
estado3 = []
for i in range(1,5):
    estaciones.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[8]/div[2]/div[{i}]/a[1]/span[1]/strong').text)
    driver.implicitly_wait(2)
    print('name done')
    km.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[8]/div[2]/div[{i}]/a[3]').text)
    driver.implicitly_wait(2)
    print('km done')
    nieve.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[8]/div[2]/div[{i}]/a[5]').text)
    print('nieve done')
    estado3.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[8]/div[2]/div[{i}]/a[2]/span/span[1]').text)
    print('estado done')
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/alvaro/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-135-c069f0bbad27>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-135-c069f0bbad27>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   estaciones.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[8]/div[2]/div[{i}]/a[1]/span[1]/strong').text)
# <ipython-input-135-c069f0bbad27>:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   km.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[8]/div[2]/div[{i}]/a[3]').text)
# <ipython-input-135-c069f0bbad27>:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   nieve.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[8]/div[2]/div[{i}]/a[5]').text)
# <ipython-input-135-c069f0bbad27>:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   estado3.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[8]/div[2]/div[{i}]/a[2]/span/span[1]').text)
# name done
# km done
# nieve done
# estado done
# name done
# km done
# nieve done
# estado done
# name done
# km done
# nieve done
# estado done
# name done
# km done
# nieve done
# estado done

# %%
KM = []
for i in km:
    i = i.split('\n')
    KM.append(i[0])
len(KM)
# Out:
# 4

# %%
sistema_iberico = pd.DataFrame([estaciones,KM,nieve,estado3])
sistema_iberico = sistema_iberico.transpose()
sistema_iberico.rename(columns = {0:'estacion',1:'KM', 2:'Nieve',3:'Estado'}, inplace = True)
sistema_iberico
# Out:
#                     estacion          KM               Nieve   Estado
# 0                 Javalambre        4/15        110 CM\nDura  Abierta
# 1  Punto de Nieve Santa Inés     1,8/1,8        90 CM\nPolvo  Abierta
# 2               Valdelinares     15/17,4  110 CM\nPolvo/Dura  Abierta
# 3                Valdezcaray  9,55/22,35              110 CM  Abierta

# %%
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
url = 'https://www.infonieve.es/estaciones-esqui/pais/espana/'
driver.get(url)
driver.implicitly_wait(2)
estaciones = []
km = []
nieve = []
estado4 = []
for i in range(1,5):
    estaciones.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[10]/div[2]/div[{i}]/a[1]/span[1]/strong').text)
    driver.implicitly_wait(2)
    print('name done')
    km.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[10]/div[2]/div[{i}]/a[3]').text)
    driver.implicitly_wait(2)
    print('km done')
    nieve.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[10]/div[2]/div[{i}]/a[5]').text)
    print('nieve done')
    estado4.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[10]/div[2]/div[{i}]/a[2]/span/span[1]').text)
    print('estado done')
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/alvaro/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-141-89f3557f028e>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-141-89f3557f028e>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   estaciones.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[10]/div[2]/div[{i}]/a[1]/span[1]/strong').text)
# <ipython-input-141-89f3557f028e>:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   km.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[10]/div[2]/div[{i}]/a[3]').text)
# <ipython-input-141-89f3557f028e>:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   nieve.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[10]/div[2]/div[{i}]/a[5]').text)
# <ipython-input-141-89f3557f028e>:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   estado4.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[10]/div[2]/div[{i}]/a[2]/span/span[1]').text)
# name done
# km done
# nieve done
# estado done
# name done
# km done
# nieve done
# estado done
# name done
# km done
# nieve done
# estado done
# name done
# km done
# nieve done
# estado done

# %%
KM = []
for i in km:
    i = i.split('\n')
    KM.append(i[0])
len(KM)
# Out:
# 4

# %%
sistema_central = pd.DataFrame([estaciones,KM,nieve,estado4])
sistema_central = sistema_central.transpose()
sistema_central.rename(columns = {0:'estacion',1:'KM', 2:'Nieve',3:'Estado'}, inplace = True)
sistema_central
# Out:
#                 estacion       KM          Nieve       Estado
# 0             La Pinilla  -/15,57  30 CM\nHúmeda  Cerr. Meteo
# 1  Puerto de Navacerrada    -/5,1           - CM      Cerrada
# 2        Sierra de Béjar  -/20,29           - CM      Cerrada
# 3              Valdesquí  -/22,24           - CM      Cerrada

# %%
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
url = 'https://www.infonieve.es/estaciones-esqui/pais/espana/'
driver.get(url)
driver.implicitly_wait(2)
estaciones = []
km = []
nieve = []
estado = []
estaciones.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[12]/div[2]/div/a[1]/span[1]/strong').text)
driver.implicitly_wait(2)
print('name done')
km.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[12]/div[2]/div/a[3]').text)
driver.implicitly_wait(2)
print('km done')
nieve.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[12]/div[2]/div/a[5]').text)
print('nieve done')
estado.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[12]/div[2]/div/a[2]/span/span[1]').text)
print('estado done')
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/alvaro/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-145-2a0da7f1eed3>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-145-2a0da7f1eed3>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   estaciones.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[12]/div[2]/div/a[1]/span[1]/strong').text)
# name done
# km done
# nieve done
# estado done
# <ipython-input-145-2a0da7f1eed3>:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   km.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[12]/div[2]/div/a[3]').text)
# <ipython-input-145-2a0da7f1eed3>:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   nieve.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[12]/div[2]/div/a[5]').text)
# <ipython-input-145-2a0da7f1eed3>:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   estado.append(driver.find_element_by_xpath(f'//*[@id="contenido"]/div[2]/div/div[12]/div[2]/div/a[2]/span/span[1]').text)

# %%
estado
# Out:
# ['Abierta']

# %%
KM = []
for i in km:
    i = i.split('\n')
    KM.append(i[0])
len(KM)
# Out:
# 1

# %%
sistema_penibetico = pd.DataFrame([estaciones,KM,nieve,estado])
sistema_penibetico = sistema_penibetico.transpose()
sistema_penibetico.rename(columns = {0:'estacion',1:'KM', 2:'Nieve',3:'Estado'}, inplace = True)
sistema_penibetico
# Out:
#         estacion          KM          Nieve   Estado
# 0  Sierra Nevada  9,84/111,4  40 CM\nHúmeda  Abierta

# %%
df1 = pd.concat([cordillera_cantabrica, sistema_central])
df = pd.concat([sistema_iberico,sistema_penibetico,pirineo_aragones,pirineo_catalan,cordillera_cantabrica,sistema_central])
df
# Out:
#                     estacion          KM               Nieve         Estado
# 0                 Javalambre        4/15        110 CM\nDura        Abierta
# 1  Punto de Nieve Santa Inés     1,8/1,8        90 CM\nPolvo        Abierta
# 2               Valdelinares     15/17,4  110 CM\nPolvo/Dura        Abierta
# 3                Valdezcaray  9,55/22,35              110 CM        Abierta
# 0              Sierra Nevada  9,84/111,4       40 CM\nHúmeda        Abierta
# 0                      Astún       28/50       185 CM\nPolvo        Abierta
# 1                  Candanchú     25/50,5       180 CM\nPolvo        Abierta
# 2                     Cerler       41/80   80 CM\nPolvo/Dura        Abierta
# 3                   Formigal      54/143  150 CM\nPolvo/Dura        Abierta
# 4                  Panticosa       16/39  135 CM\nPolvo/Dura        Abierta
# 0             Baqueira Beret     144/167       185 CM\nPolvo        Abierta
# 1                  Boí Taüll       18/45        40 CM\nPolvo        Abierta
# 2                Espot Esquí       16/25        60 CM\nPolvo        Abierta
# 3                  La Molina       51/71   70 CM\nPolvo/Dura        Abierta
# 4                    Masella       64/74   90 CM\nPolvo/Dura        Abierta
# 5                  Port Ainé     10/26,7        50 CM\nPolvo        Abierta
# 6             Port del Comte       26/50         50 CM\nDura        Abierta
# 7                   Tavascán         5/6       150 CM\nPolvo        Abierta
# 8              Vall de Nuria       5/7,6        40 CM\nPolvo        Abierta
# 9               Vallter 2000     9/13,23        65 CM\nPolvo        Abierta
# 0                Alto Campoo  1,25/30,38        170 CM\nDura        Abierta
# 1        Fuentes de Invierno    3,5/8,76       200 CM\nPolvo        Abierta
# 2                Leitariegos      -/8,25      100 CM\nHúmeda    Cerr. Meteo
# 3                     Lunada         -/8                - CM        Cerrada
# 4                  Manzaneda     -/16,75                - CM  Uso turístico
# 5                 San Isidro   15,4/31,1       190 CM\nPolvo        Abierta
# 6          Valgrande-Pajares   2,73/22,5  195 CM\nPolvo/Dura        Abierta
# 0                 La Pinilla     -/15,57       30 CM\nHúmeda    Cerr. Meteo
# 1      Puerto de Navacerrada       -/5,1                - CM        Cerrada
# 2            Sierra de Béjar     -/20,29                - CM        Cerrada
# 3                  Valdesquí     -/22,24                - CM        Cerrada

# %%
nombre = df.estacion
nuevo = []
for i in nombre:
    nuevo.append(i.replace(' ','-'))

# %%
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
n_pistas = []
remontes = []
pistas_rojas = []
pistas_verdes = []
pistas_negras = []
pistas_azules = []
precio_adultos = []
snowpark = []
for i in nuevo:
    url = f'https://www.infonieve.es/estacion-esqui/{i}/ficha-tecnica/'
    driver.implicitly_wait(4)
    driver.get(url)
    n_pistas.append(driver.find_element_by_xpath('//*[@id="contenido"]/div[2]/div/div[6]/div/div[1]/div[2]').text)
    remontes.append(driver.find_element_by_xpath('//*[@id="contenido"]/div[2]/div/div[9]/div/div[1]/div[2]').text)
    pistas_verdes.append(driver.find_element_by_xpath('//*[@id="contenido"]/div[2]/div/div[6]/div/div[2]/div[2]').text)
    pistas_rojas.append(driver.find_element_by_xpath('//*[@id="contenido"]/div[2]/div/div[6]/div/div[3]/div[2]').text)
    pistas_negras.append(driver.find_element_by_xpath('//*[@id="contenido"]/div[2]/div/div[6]/div/div[3]/div[4]').text)
    pistas_azules.append(driver.find_element_by_xpath('//*[@id="contenido"]/div[2]/div/div[6]/div/div[2]/div[4]').text)
    precio_adultos.append(driver.find_element_by_xpath('//*[@id="contenido"]/div[2]/div/div[15]/div/div/div[1]/div[1]/div/div[2]/div[2]').text)
    snowpark.append(driver.find_element_by_xpath('//*[@id="contenido"]/div[2]/div/div[12]/div/div[3]/div[2]').text)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/alvaro/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-175-3515212d352a>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-175-3515212d352a>:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   n_pistas.append(driver.find_element_by_xpath('//*[@id="contenido"]/div[2]/div/div[6]/div/div[1]/div[2]').text)
# <ipython-input-175-3515212d352a>:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   remontes.append(driver.find_element_by_xpath('//*[@id="contenido"]/div[2]/div/div[9]/div/div[1]/div[2]').text)
# <ipython-input-175-3515212d352a>:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   pistas_verdes.append(driver.find_element_by_xpath('//*[@id="contenido"]/div[2]/div/div[6]/div/div[2]/div[2]').text)
# <ipython-input-175-3515212d352a>:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   pistas_rojas.append(driver.find_element_by_xpath('//*[@id="contenido"]/div[2]/div/div[6]/div/div[3]/div[2]').text)
# <ipython-input-175-3515212d352a>:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   pistas_negras.append(driver.find_element_by_xpath('//*[@id="contenido"]/div[2]/div/div[6]/div/div[3]/div[4]').text)
# <ipython-input-175-3515212d352a>:19: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   pistas_azules.append(driver.find_element_by_xpath('//*[@id="contenido"]/div[2]/div/div[6]/div/div[2]/div[4]').text)
# <ipython-input-175-3515212d352a>:20: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   precio_adultos.append(driver.find_element_by_xpath('//*[@id="contenido"]/div[2]/div/div[15]/div/div/div[1]/div[1]/div/div[2]/div[2]').text)
# <ipython-input-175-3515212d352a>:21: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   snowpark.append(driver.find_element_by_xpath('//*[@id="contenido"]/div[2]/div/div[12]/div/div[3]/div[2]').text)

# %%
df74 = pd.DataFrame([pistas_azules,pistas_negras,pistas_rojas,pistas_verdes,precio_adultos,n_pistas,remontes,snowpark])

# %%
df7 = df74.transpose()
#df7

# %%
df7.columns
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
df7.rename(columns = {0:'pistas_azules',1:'pistas_negras',2:'pistas_rojas',3:'pistas_verdes',4:'precio_adultos',5:'n_pistas',6:'remontes',7:'Snowpark'}, inplace = True)

# %%
df.to_csv('data/dfestaciones.csv')

# %%
df7.to_csv('data/fichatecnica.csv')

# %%
data = pd.concat([df, df7])

# %%
data # tengo que meter en df7 los nombres de las estaciones asi puedo unir las dos tablas sin quede como el culo.
# Out:
#                      estacion          KM               Nieve   Estado  \
# 0                  Javalambre        4/15        110 CM\nDura  Abierta
# 1   Punto de Nieve Santa Inés     1,8/1,8        90 CM\nPolvo  Abierta
# 2                Valdelinares     15/17,4  110 CM\nPolvo/Dura  Abierta
# 3                 Valdezcaray  9,55/22,35              110 CM  Abierta
# 0               Sierra Nevada  9,84/111,4       40 CM\nHúmeda  Abierta
# ..                        ...         ...                 ...      ...
# 26                        NaN         NaN                 NaN      NaN
# 27                        NaN         NaN                 NaN      NaN
# 28                        NaN         NaN                 NaN      NaN
# 29                        NaN         NaN                 NaN      NaN
# 30                        NaN         NaN                 NaN      NaN
#
#    pistas_azules pistas_negras pistas_rojas pistas_verdes precio_adultos  \
# 0            NaN           NaN          NaN           NaN            NaN
# 1            NaN           NaN          NaN           NaN            NaN
# 2            NaN           NaN          NaN           NaN            NaN
# 3            NaN           NaN          NaN           NaN            NaN
# 0            NaN           NaN          NaN           NaN            NaN
# ..           ...           ...          ...           ...            ...
# 26            10             4           14             9         29,00€
# 27             6             -           13             4         35,00€
# 28             3             -            4             1         32,00€
# 29             6             -           15             3         29,00€
# 30            16             -            5             7         38,00€
#
#    n_pistas remontes Snowpark
# 0       NaN      NaN      NaN
# 1       NaN      NaN      NaN
# 2       NaN      NaN      NaN
# 3       NaN      NaN      NaN
# 0       NaN      NaN      NaN
# ..      ...      ...      ...
# 26       37       10       Si
# 27       23       13       Si
# 28        8        6       Si
# 29       24        4       Si
# 30       28       15       Si
#
# [62 rows x 12 columns]

# %%
pirineo_catalan_falso = tabla1[0].split('/')

# %%
nombres estacion
//*[@id="contenido"]/div[2]/div/div[2]/div[2]/div[3]/a[1]/span[1]
//*[@id="contenido"]/div[2]/div/div[2]/div[2]/div[2]/a[1]/span[1]
//*[@id="contenido"]/div[2]/div/div[4]/div[2]/div[1]/a[1]/span[1]
//*[@id="contenido"]/div[2]/div/div[4]/div[2]/div[2]/a[1]/span[1]
//*[@id="contenido"]/div[2]/div/div[6]/div[2]/div[1]/a[1]/span[1]
//*[@id="contenido"]/div[2]/div/div[6]/div[2]/div[6]/a[1]/span[1]
//*[@id="contenido"]/div[2]/div/div[8]/div[2]/div[1]/a[1]/span[1]/strong
//*[@id="contenido"]/div[2]/div/div[10]/div[2]/div[1]/a[1]/span[1]/strong

km
//*[@id="contenido"]/div[2]/div/div[2]/div[2]/div[1]/a[3]
//*[@id="contenido"]/div[2]/div/div[2]/div[2]/div[2]/a[3]
//*[@id="contenido"]/div[2]/div/div[4]/div[2]/div[1]/a[3]
//*[@id="contenido"]/div[2]/div/div[6]/div[2]/div[1]/a[3]
//*[@id="contenido"]/div[2]/div/div[8]/div[2]/div[1]/a[3]
//*[@id="contenido"]/div[2]/div/div[10]/div[2]/div[1]/a[3]

nieve
//*[@id="contenido"]/div[2]/div/div[2]/div[2]/div[1]/a[5]
//*[@id="contenido"]/div[2]/div/div[2]/div[2]/div[3]/a[5]
//*[@id="contenido"]/div[2]/div/div[2]/div[2]/div[7]/a[5]
//*[@id="contenido"]/div[2]/div/div[4]/div[2]/div[1]/a[5]
//*[@id="contenido"]/div[2]/div/div[6]/div[2]/div[1]/a[5]
//*[@id="contenido"]/div[2]/div/div[8]/div[2]/div[1]/a[5]

estado
//*[@id="contenido"]/div[2]/div/div[2]/div[2]/div[1]/a[2]/span/span[1]
//*[@id="contenido"]/div[2]/div/div[2]/div[2]/div[2]/a[2]/span/span[1]
//*[@id="contenido"]/div[2]/div/div[4]/div[2]/div[1]/a[2]/span/span[1]
